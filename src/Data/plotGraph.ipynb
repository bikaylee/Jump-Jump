# %%
import numpy as np 
import matplotlib.pyplot as plt


def plotGraph(path):
    data1 = np.genfromtxt(path+'episodes_new.txt', delimiter="\t")
    data2 = np.genfromtxt(path+'steps_new.txt', delimiter="\t")
    log_frequency = 100
    box = np.ones(log_frequency) /log_frequency
    
    plt.figure(figsize=(10,10),dpi=80)
    X = []
    Y = []
    plt.figure(1)
    
    for item in data1:
        X.append(item[0])
        Y.append(item[1])
    Y_smooth = np.convolve(Y, box, mode='same')
    ax1=plt.subplot(221)
    plt.plot(X, Y_smooth,color="y")
    plt.ylabel('steps')
    plt.xlabel('episodes')


    X = []
    Y = []
    for item in data1:
        X.append(item[0])
        Y.append(item[2])
    Y_smooth = np.convolve(Y, box, mode='same')
    ax2=plt.subplot(222)
    plt.plot(X, Y_smooth,color="y")
    plt.ylabel('scores')
    plt.xlabel('episodes')

    X = []
    Y = []
    for item in data2:
        X.append(item[0])
        Y.append(item[1])
    Y_smooth = np.convolve(Y, box, mode='same')
    ax2=plt.subplot(223)
    plt.plot(X, Y_smooth,color="y")
    plt.ylabel('Scores')
    plt.xlabel('Episodes')

    X = []
    Y = []    
    for item in data2:
        X.append(item[0])
        Y.append(item[2])
    Y_smooth = np.convolve(Y, box, mode='same')
    ax2=plt.subplot(224)
    plt.plot(X, Y_smooth,color="y")
    plt.ylabel('Relative Difference')
    plt.xlabel('Episodes')    
    
    
def plotGraph_Step_Scores(path):
    data1 = np.genfromtxt(path+'steps.txt', delimiter="\t")
    data2 = np.genfromtxt(path+'steps_new.txt', delimiter="\t")
#     data3 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     data4 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     data5 = np.genfromtxt(path+'steps.txt', delimiter="\t")
    log_frequency = 100
    box = np.ones(log_frequency) /log_frequency
    
#     plt.figure(figsize=(10,10),dpi=80)
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []
    X3 = []
    Y3 = []
    X4 = []
    Y4 = []
    X5 = []
    Y5 = []    
    for item in data1:
        X1.append(item[0])
        Y1.append(item[1])
    Y1_smooth = np.convolve(Y1, box, mode='same')
    for item in data2:
        X2.append(item[0])
        Y2.append(item[1])  
    Y2_smooth = np.convolve(Y2, box, mode='same')
#     for item in data3:
#         X3.append(item[0])
#         Y3.append(item[1])
#     Y3_smooth = np.convolve(Y3, box, mode='same')
#     for item in data4:
#         X4.append(item[0])
#         Y4.append(item[1])
#     Y4_smooth = np.convolve(Y4, box, mode='same')
#     for item in data5:
#         X5.append(item[0])
#         Y5.append(item[1])
#     Y4_smooth = np.convolve(Y5, box, mode='same')
    
    plt.figure(figsize=(10,5))
    plt.title('Steps Vs. Score',fontsize=20)
    plt.xlabel('Steps',fontsize=14)
    plt.ylabel('Scores',fontsize=14)
    plt.plot(X1,Y1_smooth,color="deeppink",label='d1')
    plt.plot(X2,Y2_smooth,color="b",label='d2')
#     plt.plot(X3,Y3_smooth,color="y",label='d3')
#     plt.plot(X4,Y4_smooth,color="m",label='d4')
#     plt.plot(X5,Y5_smooth,color="b",label='d5')
    plt.legend(loc=2)#图例展示位置，数字代表第几象限
    
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []
    X3 = []
    Y3 = []
    X4 = []
    Y4 = []
    X5 = []
    Y5 = []    
    for item in data1:
        X1.append(item[0])
        Y1.append(item[2])
    Y1_smooth = np.convolve(Y1, box, mode='same')
    for item in data2:
        X2.append(item[0])
        Y2.append(item[2])  
    Y2_smooth = np.convolve(Y2, box, mode='same')
#     for item in data3:
#         X3.append(item[0])
#         Y3.append(item[2])
#     Y3_smooth = np.convolve(Y3, box, mode='same')
#     for item in data4:
#         X4.append(item[0])
#         Y4.append(item[2])
#     Y4_smooth = np.convolve(Y4, box, mode='same')
#     for item in data5:
#         X5.append(item[0])
#         Y5.append(item[2])
#     Y4_smooth = np.convolve(Y5, box, mode='same')
    
    plt.figure(figsize=(10,5))
    plt.title('Steps Vs. Relative Difference',fontsize=20)
    plt.xlabel('Steps',fontsize=14)
    plt.ylabel('Relative Difference',fontsize=14)
    plt.plot(X1,Y1_smooth,color="deeppink",label='d1')
    plt.plot(X2,Y2_smooth,color="b",label='d2')
#     plt.plot(X3,Y3_smooth,color="y",label='d3')
#     plt.plot(X4,Y4_smooth,color="m",label='d4')
#     plt.plot(X5,Y5_smooth,color="b",label='d5')
    plt.legend(loc=2)#图例展示位置，数字代表第几象限
    
# def plotGraph_Step_RelativeDiff(path):
#     data1 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     data2 = np.genfromtxt(path+'steps_new.txt', delimiter="\t")
# #     data3 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data4 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data5 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     log_frequency = 100
#     box = np.ones(log_frequency) /log_frequency
    
#     plt.figure(figsize=(10,10),dpi=80)
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []
    X3 = []
    Y3 = []
    X4 = []
    Y4 = []
    X5 = []
    Y5 = []    
    for item in data1:
        X1.append(item[0])
        Y1.append(item[2])
    Y1_smooth = np.convolve(Y1, box, mode='same')
    for item in data2:
        X2.append(item[0])
        Y2.append(item[2])  
    Y2_smooth = np.convolve(Y2, box, mode='same')
#     for item in data3:
#         X3.append(item[0])
#         Y3.append(item[2])
#     Y3_smooth = np.convolve(Y3, box, mode='same')
#     for item in data4:
#         X4.append(item[0])
#         Y4.append(item[2])
#     Y4_smooth = np.convolve(Y4, box, mode='same')
#     for item in data5:
#         X5.append(item[0])
#         Y5.append(item[2])
#     Y4_smooth = np.convolve(Y5, box, mode='same')
    
    plt.figure(figsize=(10,5))
    plt.title('Steps Vs. Relative Difference',fontsize=20)
    plt.xlabel('Steps',fontsize=14)
    plt.ylabel('Relative Difference',fontsize=14)
    plt.plot(X1,Y1_smooth,color="deeppink",label='d1')
    plt.plot(X2,Y2_smooth,color="b",label='d2')
#     plt.plot(X3,Y3_smooth,color="y",label='d3')
#     plt.plot(X4,Y4_smooth,color="m",label='d4')
#     plt.plot(X5,Y5_smooth,color="b",label='d5')
    plt.legend(loc=2)#图例展示位置，数字代表第几象限
    
# def plotGraph_Episode_Scores(path):
#     data1 = np.genfromtxt(path+'episodes.txt', delimiter="\t")
#     data2 = np.genfromtxt(path+'episodes_new.txt', delimiter="\t")
# #     data3 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data4 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data5 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     log_frequency = 100
#     box = np.ones(log_frequency) /log_frequency
    
#     plt.figure(figsize=(10,10),dpi=80)
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []
    X3 = []
    Y3 = []
    X4 = []
    Y4 = []
    X5 = []
    Y5 = []    
    for item in data1:
        X1.append(item[0])
        Y1.append(item[2])
    Y1_smooth = np.convolve(Y1, box, mode='same')
    for item in data2:
        X2.append(item[0])
        Y2.append(item[2])  
    Y2_smooth = np.convolve(Y2, box, mode='same')
#     for item in data3:
#         X3.append(item[0])
#         Y3.append(item[2])
#     Y3_smooth = np.convolve(Y3, box, mode='same')
#     for item in data4:
#         X4.append(item[0])
#         Y4.append(item[2])
#     Y4_smooth = np.convolve(Y4, box, mode='same')
#     for item in data5:
#         X5.append(item[0])
#         Y5.append(item[2])
#     Y4_smooth = np.convolve(Y5, box, mode='same')
    
    plt.figure(figsize=(10,5))
    plt.title('Episodes Vs. Score',fontsize=20)
    plt.xlabel('Episodes',fontsize=14)
    plt.ylabel('Scores',fontsize=14)
    plt.plot(X1,Y1_smooth,color="deeppink",label='d1')
    plt.plot(X2,Y2_smooth,color="b",label='d2')
#     plt.plot(X3,Y3_smooth,color="y",label='d3')
#     plt.plot(X4,Y4_smooth,color="m",label='d4')
#     plt.plot(X5,Y5_smooth,color="b",label='d5')
    plt.legend(loc=2)#图例展示位置，数字代表第几象限
    
# def plotGraph_Episode_Steps(path):
#     data1 = np.genfromtxt(path+'episodes.txt', delimiter="\t")
#     data2 = np.genfromtxt(path+'episodes_new.txt', delimiter="\t")
# #     data3 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data4 = np.genfromtxt(path+'steps.txt', delimiter="\t")
# #     data5 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     log_frequency = 100
#     box = np.ones(log_frequency) /log_frequency
    
#     plt.figure(figsize=(10,10),dpi=80)
    X1 = []
    Y1 = []
    X2 = []
    Y2 = []
    X3 = []
    Y3 = []
    X4 = []
    Y4 = []
    X5 = []
    Y5 = []    
    for item in data1:
        X1.append(item[0])
        Y1.append(item[1])
    Y1_smooth = np.convolve(Y1, box, mode='same')
    for item in data2:
        X2.append(item[0])
        Y2.append(item[1])  
    Y2_smooth = np.convolve(Y2, box, mode='same')
#     for item in data3:
#         X3.append(item[0])
#         Y3.append(item[1])
#     Y3_smooth = np.convolve(Y3, box, mode='same')
#     for item in data4:
#         X4.append(item[0])
#         Y4.append(item[1])
#     Y4_smooth = np.convolve(Y4, box, mode='same')
#     for item in data5:
#         X5.append(item[0])
#         Y5.append(item[1])
#     Y4_smooth = np.convolve(Y5, box, mode='same')
    
    plt.figure(figsize=(10,5))
    plt.title('Episodes Vs. Steps',fontsize=20)
    plt.xlabel('Episodes',fontsize=14)
    plt.ylabel('Steps',fontsize=14)
    plt.plot(X1,Y1_smooth,color="deeppink",label='d1')
    plt.plot(X2,Y2_smooth,color="b",label='d2')
#     plt.plot(X3,Y3_smooth,color="y",label='d3')
#     plt.plot(X4,Y4_smooth,color="m",label='d4')
#     plt.plot(X5,Y5_smooth,color="b",label='d5')
    plt.legend(loc=2)#图例展示位置，数字代表第几象限

plotGraph("/Users/wencongshe/Desktop/Malmo-0.37.0-Mac-64bit_withBoost_Python3.7/Python_Examples/")
plotGraph_Step_Scores("/Users/wencongshe/Desktop/Malmo-0.37.0-Mac-64bit_withBoost_Python3.7/Python_Examples/")
# plotGraph_Step_RelativeDiff("/Users/wencongshe/Desktop/Malmo-0.37.0-Mac-64bit_withBoost_Python3.7/Python_Examples/")

# %%
# Out:
#   File "<tokenize>", line 8
#     data2 = np.genfromtxt(path+'steps.txt', delimiter="\t")
#     ^
# IndentationError: unindent does not match any outer indentation level
